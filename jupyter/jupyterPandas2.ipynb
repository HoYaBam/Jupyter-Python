# %% [markdown]
# # pandas 기초 실습

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

plt.rc('font', family=font)

df = pd.read_csv('인구현황.csv', encoding='cp949', header=1, index_col=0)
del df['2022년03월_계_연령구간인구수'], df['2022년03월_계_총인구수']


columns = []
for i in range(101):
    columns.append(str(i) + '세')

data = df.iloc[:, :101]
data.columns = columns

name = input('원하는 지역을 입력하세요 : ')
result = data.index.str.contains(name)
re_data = data[result]
re_data.T.plot()
plt.show()
# Out:
# 원하는 지역을 입력하세요 : 가수원동

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

plt.rc('font', family=font)

df = pd.read_csv('인구현황.csv', encoding='cp949', header=1, index_col=0)
df = df.div(df['2022년03월_계_총인구수'], axis=0)
del df['2022년03월_계_총인구수'], df['2022년03월_계_연령구간인구수']


ct = []
for i in df.index:
    if len(i) < 22 and i.count('0',0 , len(i)) > 5 and '구' not in i:
        ct.append(i)
        
df = df.drop(ct) 

df = df.iloc[:, :101]
name = input('원하는 지역의 이름을 입력해주세요 : ')
a = df.index.str.contains(name)
df2 = df[a]

df.loc[np.power(df.sub(df2.iloc[0], axis=1), 2).sum(axis=1).sort_values().index[:5]].T.plot()

plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요 : 가수원동
