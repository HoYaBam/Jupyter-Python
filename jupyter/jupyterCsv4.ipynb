# %% [markdown]
# # 인구현황

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

with open('인구현황.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f, delimiter=',')
    header = next(data)

    ages = []
    ages1 = []
    for row in data:
        if '가수원동' in row[0]:
            for i in range(3,104):
                ages.append(int(row[i]))
        if '범서읍' in row[0]:
            print(row)
            for i in range(3,104):
                ages1.append(int(row[i]))
    plt.plot(ages)
    plt.show()
    
    plt.plot(ages1)
    plt.show()
# Out:
# ['울산광역시 울주군 범서읍(3171025900)', '69484 ', '69484 ', '360 ', '367 ', '424 ', '479 ', '498 ', '638 ', '737 ', '765 ', '774 ', '910 ', '875 ', '919 ', '901 ', '941 ', '1062 ', '940 ', '946 ', '1005 ', '1051 ', '977 ', '1006 ', '1061 ', '990 ', '963 ', '941 ', '884 ', '868 ', '841 ', '733 ', '728 ', '671 ', '622 ', '639 ', '635 ', '595 ', '664 ', '699 ', '731 ', '851 ', '938 ', '1152 ', '1119 ', '1237 ', '1135 ', '1235 ', '1284 ', '1312 ', '1428 ', '1513 ', '1504 ', '1648 ', '1577 ', '1510 ', '1574 ', '1349 ', '1279 ', '1308 ', '1134 ', '963 ', '1071 ', '1025 ', '1092 ', '885 ', '841 ', '716 ', '675 ', '654 ', '607 ', '484 ', '450 ', '365 ', '373 ', '309 ', '291 ', '297 ', '271 ', '160 ', '231 ', '206 ', '231 ', '197 ', '173 ', '168 ', '144 ', '132 ', '90 ', '76 ', '102 ', '65 ', '46 ', '48 ', '31 ', '33 ', '13 ', '13 ', '9 ', '8 ', '3 ', '4 ', '5 ', '0 ', '34921 ', '34921 ', '186 ', '195 ', '204 ', '262 ', '269 ', '334 ', '377 ', '416 ', '408 ', '443 ', '434 ', '479 ', '461 ', '471 ', '56
# ...

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

with open('인구현황.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f)
    m = []
    w = []
    
    for row in data:
        if '가수원동' in row[0]:
            for i in range(106, 207):
                m.append(int(row[i]))
                w.append(int(row[i+103]))
            
    plt.title('대전 가수원동 남여 인구 비율')
    plt.plot(m, label='남자')
    plt.plot(w, label='여자')
    plt.legend()
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc
import re

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

west_gu = []
dong_gu = []
yooseong_gu = []
daedeok_gu = []

with open('인구현황.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f)
    
    
   
    
    for row in data:
        if '대전광역시 서구 (' in row[0]:
            for i in range(3, 104):
                    west_gu.append(int(row[i]))
        if '대전광역시 동구 (' in row[0]:
            for i in range(3, 104):
                    dong_gu.append(int(row[i]))
        if '대전광역시 유성구 (' in row[0]:
            for i in range(3, 104):
                    yooseong_gu.append(int(row[i]))
        if '대전광역시 대덕구 (' in row[0]:
            for i in range(3, 104):
                    daedeok_gu.append(int(row[i]))
            
    plt.title('대전 구별 인구 비율')
    plt.plot(western, label='서구')
    plt.plot(dong_gu, label='동구')
    plt.plot(yooseong_gu, label='유성구')
    plt.plot(daedeok_gu, label='대덕구')
    plt.legend()
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc
import re

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)


loc = ['대전광역시 서구 (', '대전광역시 동구 (', '대전광역시 유성구 (', '대전광역시 대덕구 (','대전광역시 중구 (']

with open('인구현황.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f)
    
    
   
    
    for row in data:
        for i in range(0, 4):
            gu = []
            if loc[i] in row[0]:
                for p in range(3, 104):
                    gu.append(int(row[p]))
                plt.plot(gu, label=loc[i][0:9])   
    
            
    plt.title('대전 구별 인구 비율')
    plt.legend()
    plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = r'C:/windows/Fonts/gulim.ttc'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

f = open('인구현황.csv', 'r', encoding='cp949')

data = csv.reader(f)
# m = []
# f = []
for row in data:
    if '대전광역시  (' in row[0]:
        m = [int(val)*-1 for val in row[106:207]]
        f = [int(val) for val in row[209:]]
        
plt.barh(range(101), m, label='남')
plt.barh(range(101), f, label='여')
plt.legend(loc='lower right')
plt.legend(loc='best')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = r'C:/windows/Fonts/gulim.ttc'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

f = open('10구분연령.csv', 'r', encoding='cp949')

data = csv.reader(f)

loc = ['서울특별시', '대구광역시', '부산광역시', '인천광역시', '울산광역시', '대전광역시', '광주광역시']



for row in data:
    for i in range(7):
        city = []
        if loc[i] in row[0]:
            for j in range(3,14):
                city.append(int(row[j]))
            plt.plot(city, label=loc[i])

plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = r'C:/windows/Fonts/gulim.ttc'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

f = open('10구분연령.csv', 'r', encoding='cp949')

data = csv.reader(f)

loc = ['서울특별시', '대구광역시', '부산광역시', '인천광역시', '울산광역시', '대전광역시', '광주광역시']



for row in data:
    for i in range(7):
        city = []
        if loc[i] in row[0]:
            for j in range(3,14):
                city.append(int(row[j]))
            plt.plot(city, label=loc[i])
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = r'C:/windows/Fonts/gulim.ttc'
font = font_manager.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

f = open('고용형태별근로시간.csv', 'r', encoding='cp949')

data = csv.reader(f)
next(data)
next(data)

title = []
time = []
for row in data:
    title.append(row[0])
    time.append(row[2])

f.axex = plt.subplot(3,4)
f.set_size_inches((20,15))
plt.title('고용형태별 근로시간')
plt.pie(time, labels=title, autopct="%.1f%%")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-900fefc05214> in <module>
#      18     time.append(row[2])
#      19
# ---> 20 f.axex = plt.subplot(3,4)
#      21 f.set_size_inches((20,15))
#      22 plt.title('고용형태별 근로시간')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
# ...

# %%
()
