# %%
import requests
params = {'firstname':'Ryan','lastname':'Mitchell'}
r = requests.post('http://pythonscraping.com/pages/processing.php', data={'firstname':'Ryan','lastname':'Mitchell'})

print(r.text) #폼을 전송하면 페이지 콘텐츠가 반환됩니다.

params = {'query':'python'}
rs = requests.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&', data=params)
print(rs.text)
# Out:
# Hello there,  !
# ...

# %%
import requests, json
data = {'id':'hong5','pwd':'4444', 'name':'자동', 'email':'test@test.com'}
URL = 'http://localhost:8090/member/addMember.do'
res = requests.post(URL, data=data)
print(res.text)
# Out:
#
#
#
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="UTF-8">
#     <style>
#       #container {
#         width: 100%;
#         margin: 0px auto;
#           text-align:center;
#         border: 0px solid #bcbcbc;
#       }
#       #header {
#         padding: 5px;
#         margin-bottom: 5px;
#         border: 0px solid #bcbcbc;
#          background-color: lightgreen;
#       }
#       #sidebar-left {
#         width: 15%;
#         height:700px;
#         padding: 5px;
#         margin-right: 5px;
#         margin-bottom: 5px;
#         float: left;
#          background-color: yellow;
#         border: 0px solid #bcbcbc;
#         font-size:10px;
#       }
#       #content {
#         width: 75%;
#         padding: 5px;
#         margin-right: 5px;
#         float: left;
#         border: 0px solid #bcbcbc;
#       }
#       #footer {
#         clear: both;
#         padding: 5px;
#         border: 0px solid #bcbcbc;
#          background-color: lightblue;
#       }
# ...

# %%
import requests

files = {'uploadFile': open('files/Python-logo.png', 'rb')}
r = requests.post('http://pythonscraping.com/pages/processing2.php', files=files)
print(r.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-d5ec9af2a4b5> in <module>
#       1 import requests
#       2
# ----> 3 files = {'uploadFile': open('files/Python-logo.png', 'rb')}
#       4 r = requests.post('http://pythonscraping.com/pages/processing2.php', files=files)
#       5 print(r.text)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files/Python-logo.png'
