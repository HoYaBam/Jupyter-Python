# %% [markdown]
# # 생일 일때 날씨 그래프

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)


with open('djit.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f, delimiter=',')
    next(data)
    
    lowest = []
    Average = []
    Best = []
    for row in data:
        if '08-06' in row[0][5:10]:
            if row[0] not in bsdays:
                lowest.append(float(row[2]))
                Average.append(float(row[3]))
                Best.append(float(row[4]))
    
    
    plt.plot(Best, label='최고')
    plt.plot(lowest, label='최저')
    plt.plot(Average , label='평균')
    
    plt.show()
    
    plt.hist(Best)
    plt.show()
    plt.hist(lowest)
    plt.show()
    plt.hist(Average)
    
    plt.show()

# %%
import matplotlib.pyplot as plt
import random

dict = []
dicts = []
for j in range(30):
    for i in range(1000):
        dict.append(random.randint(1,9899))
    dicts.append(dict)
plt.hist(dict)
plt.show()
plt.boxplot(dicts)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

aug = []
jan = []

with open('djit.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f, delimiter=',')
    next(data)
    
    for row in data:
        if '08' in row[0][5:7]:
            aug.append(float(row[-1]))
        if '01' in row[0][5:7]:
            jan.append(float(row[-1]))

plt.hist(aug, bins=100, color='r', label='Aug')
plt.hist(jan, bins=100, color='b', label='Jan')
plt.legend()
plt.show()
plt.boxplot(aug)
plt.boxplot(jan)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

month = [[],[],[],[],[],[],[],[],[],[],[],[]]

with open('djit.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f, delimiter=',')
    next(data)
    
    for row in data:
        if row[-1] != '':
            month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

font_path = r'C:/windows/Fonts/gulim.ttc'
font = fm.FontProperties(fname=font_path, size=16).get_name()
rc('font', family=font)

month = [[],[],[],[],[],[],[],[],[],[],[],[]]

with open('djit.csv', 'r', encoding='cp949') as f:
    data = csv.reader(f, delimiter=',')
    next(data)
    
    for row in data:
        if row[-1] != '':
            month[int(row[0][5:7])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()
