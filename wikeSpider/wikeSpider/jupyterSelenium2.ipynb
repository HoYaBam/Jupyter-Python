# %% [markdown]
# # 셀레니움 실습
# ## 게임순위 타이틀 가져오기
# ## 각 게시글의 메인 글 가져오기

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(executable_path='./chromedriver.exe')
url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EA%B2%8C%EC%9E%84%EC%88%9C%EC%9C%84"
driver.get(url)
time.sleep(3)


standing = 1

for j in range(1, 21):
    for i in range(1,6):
        gameTitle = driver.find_element_by_xpath('//*[@id="mflick"]/div/div/div[{}]/div[{}]/strong/a'.format(j,i))
        print(standing," : " , gameTitle.text)
        standing += 1
    time.sleep(2)
    nextTitle = driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/div[2]/div/div/div[3]/div/a[2]')
    nextTitle.click()
# Out:
# <ipython-input-9-064d95751fa0>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver.exe')
# <ipython-input-9-064d95751fa0>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   gameTitle = driver.find_element_by_xpath('//*[@id="mflick"]/div/div/div[{}]/div[{}]/strong/a'.format(j,i))
# 1  :  리그 오브 레전드
# 2  :  FIFA 온라인 4
# 3  :  PUBG: 배틀그라운드
# 4  :  던전앤파이터
# 5  :  로스트아크
# <ipython-input-9-064d95751fa0>:19: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   nextTitle = driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/div[2]/div/div/div[3]/div/a[2]')
# 6  :  소울워커
# 7  :  빌런마스터 : DEAD OR ALIVE
# 8  :  뱀파이어 키우기
# 9  :  기적의 검
# 10  :  초인의 시대: 방치형 키우기
# 11  :  메이플스토리
# 12  :  레알팜
# 13  :  블레이드 키우기
# 14  :  모여봐요 동물의 숲
# 15  :  구미호 키우기
# 16  :  로블록스
# 17  :  서든어택
# 18  :  제이드 다이너스티
# 19  :  소시지맨
# 20  :  스케치퀴즈
# 21  :  마인크래프트
# 22  :  작혼 -쟝타마-
# 23  :  원신
# 24  :  오버워치
# 25  :  발로란트
# 26  :  카트라이더
# 27  :  알투비트
# 28  :  브롤스타즈
# 29  :  콜 오브 듀티: 모바일
# 30  :  데몬헌터
# 31  :  무사 키우기 - 동양판타지 방치형 RPG
# 32  :  트라하 인피니티
# 33  :  배틀그라운드 모바일
# 34  :  크레이지 아케이드 비엔비
# 35  :  포트나이트
# 36  :  아키에이지
# 37  :  스타크래프트 : 리마스터
# 38  :  레이지 오브 데스티니
# 39  :  디지몬 슈퍼럼블
# 40  :  엘든 링
# 41  :  히어로즈 테일즈
# 42  :  디아블로 II: 레저렉션
# 43  :  쿠키런: 킹덤
# 44  :  태왕: 가람의 길
# 45  :  테일즈런너
# 46  :  흑마검사 키우기
# 47  :  팔라독 택틱스
# 48  :  재능 삼킨 마법사
# 49  :  포켓몬 GO
# 50  :  디아블로 이모탈
# 51  :  네이버 게임 라운지
# 52  :  에루아 사가
# 53  :  카트라이더 러쉬플러스
# 54  :  바람의나라: 연
# 55  :  피망 뉴맞고
# 56  :  이사만루21
# 57  :  피파 모바일
# 58  :  전국구 : 권력의 법칙
# 59  :  구스 구스 덕
# 60  :  랭커
# 61  :  아이들엔젤 : 여신전쟁
# 62  :  아이온
# 63  :  리니지
# 64  :  천애명월도M
# 65  :  대항해의길
# 66  :  끄투
# 67  :  겟앰프드
# 68  :  포켓몬 유나이트
# 69  :  이터널 리턴
# 70  :  타이젬 바둑
# 71  :  킹덤삼국
# 72  :  바람의나라
# 73  :  아이온 클래식
# 74  :  좀비고등학교
# 75  :  달토끼 키우기
# 76  :  넷마블 윷놀이
# 77  :  천하제일상거상
# 78  :  Pokémon LEGENDS 아르세우스
# 79  :  컴투스프로야구V22
# 80  :  어몽 어스
# 81  :  냥코 대전쟁
# 82  :  전략적 팀 전투: 심판
# 83  :  한게임 신맞고
# 84  :  언디셈버
# 85  :  던전앤파이터 모바일
# 86  :  마피아42
# 87  :  별의 커비 디스커버리
# 88  :  신영웅전설
# 89  :  리그 오브 레전드: 와일드 리프트
# 90  :  Grand Theft Auto V
# 91  :  케페우스M
# 92  :  공포의 술래잡기
# 93  :  하스스톤
# 94  :  이스케이프 프롬 타르코프
# 95  :  솔라 리바이벌
# 96  :  사이퍼즈
# 97  :  엘소드
# 98  :  패스 오브 엑자일
# 99  :  월드 오브 워크래프트: 어둠땅
# 100  :  한게임 바둑

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome(executable_path='./chromedriver.exe')
url = "https://www1.president.go.kr/petitions/?c=37&only=2&page=1&order=1"
driver.get(url)
time.sleep(3)

# 청와대에 있는 글을 하나하나 씩 글 가져오기
# 페이지 글을 가져오기

count = 1
while True:
    for i in range(1,12):
        if i == 11:
            pageNext = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[2]/a')
            pageNext.click()
            count += 1
            time.sleep(3)
            break
        for j in range(1,8):
            page = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[2]/div[2]/ul/li[{}]/div/div[2]/a'.format(j))
            page.click()
            time.sleep(4)
            pageText = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div[1]/div/div[1]/div/div[4]/div[2]')
            print(pageText.text)
            driver.back()
            time.sleep(5)

        pageNext = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[{}]/a[{}]'.format(count,i))
        pageNext.click()
        time.sleep(5)
# Out:
# <ipython-input-22-1e11b6c6abe2>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='./chromedriver.exe')
# <ipython-input-22-1e11b6c6abe2>:21: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   page = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[2]/div[2]/ul/li[{}]/div/div[2]/a'.format(j))
# <ipython-input-22-1e11b6c6abe2>:24: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   pageText = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div[1]/div/div[1]/div/div[4]/div[2]')
# 저는 장애자녀를 키우며 은행에 근무하던 열혈엄마였습니다 .하지만 코로나19로 인해 자녀의 재활치료기관이 문을 닫고 장애활동보조인의 접촉제한이 많아져 엄마인 제 손길이 필요한 환경이 늘었고
# 코로나19로 학교에 가지못하는 날이 많아지며 걱정이 늘었습니다
# 자녀의 몸상태는 재활을 하지못해 날로 악화되었고
# 아침에 출근하는 제 마음은 무거웠고 매일을 죄책감에 시달렸습니다. 자녀가 쓰러지는 일이 재활치료중단이후 급속히 늘어 담당 책임자에게 가족돌봄휴가를 사용하여 자녀를 정밀 검사받게하고 싶다고 하였으나
# 제 공백으로 인해 타직원들의 근무환경악화는 생각안하냐며 가족돌봄휴가결재 신청 조차 받아주지 않았습니다
# 또한 저는 20대여직원의 직장내괴롭힘을 당하던 때라서 출퇴근이 정말 고역이였습니다
# 승진을 빌미로 카드실적강요를 당해 정말 최선을 다해 실적도 전국10위내에 링크되었어도 승진에 낙방하는등 희망고문으로 인해 우울증도 심해졌고
# 극단적인 ** 생각까지 들어 1월말 인사이동발표후 사표를 쓰게 되었습니다
# 하지만 이 모든게 코로나블루로 인해 벌어진 일음을 인식했지만 이미 상황은 퇴사한 상태였고
#
# 제 경력을 꺽어버린 이 코로나19사태로 인한 퇴직을 청원휴직으로 돌려 경력을 이어나가고 싶습니다
#
# 정부는 자영업자 보호방안만 마련하지 마시고
# 정부는 코로나19로 인해 퇴사한 워킹맘 구제에도 힘써주세요
# 특히 장애쪽은 상황이 심각할 정도로 어머니들이 실업중입니다ᆢ
# 저는 다시 은행에나가 열심히 일하고 싶습니다
# 감사합니다
#
# [본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다]
# <ipython-input-22-1e11b6c6abe2>:29: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   pageNext = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[{}]/a[{}]'.format(count,i))
# 저는 2021년 10월 21일 대전 대덕구 **에 위치한 **건설에 2번째 설치된 타워크레인 기사로 채용된 *** 이라고합니다.
#
# 저는 **노총 타워크레인분과 조합원이고
# 임대사 (주)**타워와 근로계약을 체결하고 **건설 2번째 설치 타워크레인 조종사로 채용이 되었습니다.
#
# 그런데 오늘 2021년 10월 26일
# **노총 타워크레인분과와 **노총 타워크레인조종사연합에서 저의 채용을 취소할때까지
# 충청도지역 두 노동조합조합원이 채용되어있는 **타워 장비가동을 멈추겠다고 임대사를 협박하고 장비가동을 멈췄습니다.
# (저의 채용을 취소시키고 두단체소속 조합원을 채용하게하려는목적입니다.)
#
# 6개현장 총 15대의 장비가 멈춰섯으며 각 현장의 피해금액은 상상할수없을정도로 피해가 심각한 상황입니다. 이렇게 공사에 차질이 생겨 피해를본 공사비용을 임대사 **타워에 구상권을 청구하게하고 저의 채용을 취소하지않으면 장비가동을 하지않겠다고 협박하고있습니다
#
# 저는 엄청난 압박감속에서 자살하고싶다는 생각까지 들어 대덕경찰서를 찾아갔으나 직접적인 협박과 피해사실이 없다며 고발을 할수없고 도와줄수없다는 말을 들었습니다
#
# 정말 억울하고 미처버릴것같습니다 이러한 사태를 만들어 가고있는 **노총과,**노총 타워크레인연합 지도부와 장비가동을 멈춘 두 노조소속 기사들을 조사해주시고 이억압된 환경에서 벗어날수있게 처벌해주시길 부탁드립니다.
#
#
# 채용절차의 공정화에관한법률
# 제4조2항(채용강요 등의금지)
# 공동채용 강요등으로 조사를 해주셨으면합니다.
#
# 제가 피해를 보지않도록 더는 나쁜생각을 하지않도록 빠른조치 부탁드립니다.
#
# [본 게시물의 일부 내용이 국민 청원 요건에 위배되어 관리자에 의해 수정되었습니다]
# <ipython-input-22-1e11b6c6abe2>:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   pageNext = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[2]/a')
# ▢ 조달청의 과도한 이중처벌 기업 죽이기 제도 개정요청
#
# 조달청 물품 다수공급자계약 2단계경쟁 업무처리기준 관련
# 품질관리 제재 이중처벌(거래정지 및 감점제재 2년간 부과) 조항 개정 요청
#
# ○ 조달청의 위엄한 이중처벌의 편익보다 국민의 권익침해 및 기업의 생존을 어렵게 하고 공정성과 공익성 또한 부족하여, 결국 국민의 피해가 매우 더 큰 과도한 이중처벌제도의 개선을 요청합니다.
# [허가(등록을 고치면 위법) 그대로 납품하므로 잘못이 없는데도 검사제도의 맹점을 간과했다고 처벌한다면 맹한 제품만 처벌 해야지 그 처벌 이후 또다시 이중으로 잘못 없는 다른 좋은 제품까지 모두를 과도하게 이중처벌하면 안돼요.]
#
# ◎ 요청내용 :
# ① 조달청이 선정한 다수공급자제품을 공공기관에 납품하는 자가 최초 1억원 이후 2억원 납품시마다 실시하는 ‘조달물자 검사 대상물품 및 검사기준’ 과 “조달물자 전문기관검사 업무규정” 과 ‘물품구매계약 품질관리 특수조건’ 및 ‘조달청 물품 다수공급자계약 2단계경쟁 업무처리기준’에 따라 전문검사기관 검사에 불합격한 경우 ⟪해당제품 거래정지와 MAS2(다수공급자계약제품 경쟁입찰)단계 입찰에서 낙찰자 선정평가 시 해당 사업자의 다른제품까지 모두 품질관리 점수항목 감점제재로 이중처벌⟫을 하고 있으나 계약상대자인 납품자가 조달청에서 당초 선정 등록 시 제출한 시험성적서 성능 그대로 납품하는 제품의 품질검사 시험인 경우 당초 성능대로 납품하는지의 품질유지 확인 검사이므로 당초 값으로 시험하는 것이 타당한데도 이 당초 값을 적용하지 않고 더 높은 값으로 시험하여 불합격된 결과를 불복하며 ‘납품자(계약상대자)가 재시험 요청하거나, 구매자(수요기관)가 재시험을 요청할 경우 재시험을 수용’해야 합니다.
#
# ※ 개정요청 : 「조달물자 전문기관검사 업무규정」 제23조(시험결과에 대한 이의)
# “① 계약상대자 및 수요기관의 장이 시험결과에 대하여 이의를 제기하면 조달청장은 시험방법 및 절차 등을 고려하여 확인시험이 필요하다고 판단하는 경우 전문검사기관의 장에게 확인시험을 요청하고~” 의 위 규정에서 조달청장이 ‘필요하다고 판단’하는 고려의 기준근거가 명확하지 않고 적용사례를 찾아보기 힘들며 ‘갑’만을 위한 문구로 ‘을’에게는 불리한 전형적인 ‘갑’의 입장으로 판단하겠다는 내용을 삭제하고
# “① 계약상대자 및 수요기관의 장이 시험결과에 대하여 이의를 제기하면 조달청장은 전문검사기관의 장에게 확인시험을 요청하고~” 로 수정하여 모두에게 동등하며 분명하고 명확한 문구로 개정을 요청합니다.
# - 상기와 관련하여 공공기관(구매자, 수요기관)이 전문검사기관의 검사(불합격 결과)를 신뢰하지 못해 수요기관이 자체 검사로 변경하고 ‘수요기관의 자체 검사에 합격’하여 납품한 경우, 원인행위가 소멸되었으므로 거래정지 뿐만이 아니라 품질관리 감점제재를 하지 않아야하며 이미 처분한 거래정지도 즉시 소멸하여야 하고 이후 납품자가 신청하는 재계약 및 계약연장 등에 불이익 또한 없도록 해야 합니다.
#
# 1. 조달청 나라장터종합쇼핑몰 제품 품질관리제도의 가혹한 2중 처벌의 규정 : 불합격 제품의 거래정지뿐만 아니라 그 기업(사업자)의 다른 일반제품 모두를 또다시 2중 처벌로 감점제재하는 것은 해당기업의 다른 제품의 사업까지 규제하여 기업을 못하게 하는 헌법을 초월하는 너무 가혹한 처벌입니다.
#
# (1) 조달청이 품질관리 전문검사기관을 통한 기업 죽이기 유형
# - MAS2단계 경쟁입찰 해당 쇼핑몰 등록제품의 엄격한 품질관리 검사조건으로 제품 가격기준 최초 납품의 경우 1억원이상 이후 2억원이상 납품시 마다 매번 납품할 제품의 품질검사를 납품자가 많은 비용을 부담하며 전문검사기관에 의뢰 실시하여 불합격시 해당 등록제품의 거래정지와 또 다른 처벌인 감점제재로 이 거래정지 기간과 감점제재 기간 또한 크게 다른 이중처벌의 품질관리 제도를 운영(품질검사 불합격시 거래정지 1개월과 감점 제재 2년간(기업생존이 어려운 오랜기간)의 이중처벌을 함)
#
# - 위 당초 불합격 처분 받은 제품은 거래정지(1개월) 제재가 끝나 그 동일제품을 조달청 나라장터종합쇼핑몰을 통해 공공기관에 납품하고 있는데 위 ‘동일 제조사가 나라장터쇼핑몰에 등록한 다른 모든 제품’의 품질관리 점수에 감점 제재(2년)로 다른 제품까지 연좌제식으로 처벌하는 것은 기업 죽이기 제도와 다를 바 없음[당초 합격당시 제품을 털끝 하나 고치지 않고(좋게 또는 나쁘게 고치면 위반) 납품하는 제품인데도 매우 극소수 1개 품목에 제조사가 제시한 등록 당시 당초 시험 값을 적용하지 않고 시험기준이내라고 하며 당초 시험 값보다 높은 값을 적용해서 시험하여 불합격 처분을 받은 기업에게 거래정지 뿐만이 아니라 다른 종류의 모든 제품에 품질관리 점수까지 감점제재]
#
# - 품질관리가 엄격해야하는 것에는 동의하나, MAS(다수공급자계약제품)2단계 경쟁입찰의 품질관리 점수 감점제재는 불합격 받았던 제품의 사업자만 같아도 그 기업의 다른 제품까지 모두 2점(종합평가방식) ~ 6점(표준평가방식)을 감점하고 있음, 이는 MAS2단계 경쟁입찰에서 업체들의 평가 합계점수가 1점이내의 근소한 점수차이로 1순위에 선정되는 입찰임을 감안할 때 2~6점의 감점은 매우 큰 점수로 MAS2단계 경쟁입찰에서 사실상 낙찰 선정되기는 불가능하여 기업생존 유지가 어려움(MAS2단계 경쟁입찰을 피해서 수의계약에만 의존하여 사업하는 것은 고용창출도 고용유지도 할 수 없는 고용 없는 1인 기업정도가 아닌 이상 기업생존이 사실상 불가능)
#
# (2) 검사결과 불합격된 제품만 제재 필요
# - 품질관리 검사에 불합격제품만 거래정지 처벌을 하고 연좌제 성격의 이중처벌인 다른 제품을 감점제재로 처벌하는 것은 금지해야 합니다.(예시, 불합격 제품은 ‘공기조화기’인데 사업자가 같다고 정상제품인 ‘공기청정기’까지 제재해서는 안됨)
#
# 2. 사후 검증에 의해 잘 못이 없는 기업에게 처벌이 이루어졌다고 판결된다면 그에 따른 피해는 회복이 불가능하므로 품질관리 절차와 제도의 개정이 절실히 필요합니다.
#
# (1) 정부조달제도의 납품자가 품질검사에 불복하여 재시험 요청하거나 구매 수요기관에서 재시험을 요청할 경우 “재시험 수용” 규정을 추가하여 억울한 피해자가 없도록 해주세요.
# - 납품기업이 많은 검사비용을 부담하며 조달업무 규정에 의해 실시하는 전문검사기관 품질검사에 이해충돌 또는 검사의 잘못이 있을 수 있어 납품기업의 재시험 요청시 즉시 ‘재시험을 수용’하여 재시험 실시해야 합니다.
# [단, 납품기업의 무분별한 불복의 재시험 요청을 없애기 위해 재시험 결과에서도 불합격될 경우 해당 처벌(제재)을 최고 수위로 엄격히 적용]
#
# (당초 조달청 나라장터쇼핑몰에 제품 등록시 동일제품 그대로 납품하는 제품을 전문검사기관의 품질검사 시 당초 등록당시 제품성능 평가에 적용한 시험 값을 제시했으나 그 시험 값으로 성능시험을 하지 않아 불합격된 경우 등 혹여 절차나 기준의 착오 또는 단순 실수 등과 같이 기업의 고의가 없는 보통의 성실한 기업에게 큰 피해가 발생할 수 있으므로 그 피해에 따른 억울함이 없도록 소명의 기회로 계약대상자(납품기업 또는 수요기관)가 재시험을 요청할 경우 민원 재검증 등 인도적 차원에서 이를 수용하고 재시험을 실시해야 조달청의 품질검사 제도를 납품자와 구매자가 신뢰할 수 있음)
#
#
# ○ 조달청의 위엄적 처벌이 하도 억울하여 헌법을 참조 비유해 봅니다.
# (수요기관에서도 이런 조달청의 위엄적 처벌을 ‘갑’질이라고 합니다.)
#
# ◉ 대한민국헌법 제13조 제1항이 정한 “이중처벌 금지의 원칙”
# (슈퍼 갑이며 공공기관 납품자선정과 구매 및 검사를 관장하는 조달청이 위탁 실시하는 전문검사기관의 검사결과를 계약대상자인 납품자와 구매자가 불복하여 재시험요청을 했으나 거절하고 거래정지 처벌에 이어 또 다시 다른 제품까지 '이중처벌 제재'를 하는 억울한 건에 수요기관(공공기관)인 구매자가 조달청이 위탁하여 실시한 검사결과를 신뢰하지 못해 수요기관인 구매자가 직접 검사를 하여 합격 납품한 경우 그 처벌을 소멸해야 합니다.)
#
# 제13조 ①모든 국민은 행위 시의 법률에 의하여 범죄를 구성하지 아니하는 행위로 소추되지 아니하며, 동일한 범죄에 대하여 거듭 처벌받지 아니한다.
# ②모든 국민은 소급입법에 의하여 참정권의 제한을 받거나 재산권을 박탈당하지 아니한다.
# ③모든 국민은 자기의 행위가 아닌 친족의 행위로 인하여 불이익한 처우를 받지 아니한다.
# *(노동부장관님 보세요!!!!) 보완해서 다시 올린 내용입니다*
# 충청도의 한 택배터미널에서 일하는 일용직근로자입니다
# 저를 비롯해 약400명의 택배종사자들이 노동청공무원의 안일한 일처리로 일반체당금을 받지 못할 위기에 처해 있습니다
# 퇴직급여보장법에 계약의 형식을 떠나 4주평균 주15시간 이상
# 근로하는 자들에게 퇴직금을 지급해야 함에도 불구하고
# 관내에서 대량의 체불근로자가 발생하자 9개월간 사건을 끌다가 공문형식으로 받은 결과가 일용직근로자는 아무도 퇴직금을 받을 수 없다는....
# 이처럼 말도 되지않는 결론을 내려놓고 행정심판으로 가라는 식의 직무유기를 행하고 있는 자들이 노동청에서
# 노무관련업무를 종사하는 공무원이라니요 그들의 자질이 매우 의심스럽습니다
# 공문의 내용을 구체적으로 밝힐 수는 없지만 일부내용을 인용하자면 다음과 같습니다
# < 노동지청에서 보낸 공문내용>
# *해당 근로자들은 근로를 제공하는 날에만 근로계약이 성립되는 일용직근로자로서 달리 판단할 사정이 없는한 2019년12월 18일( 이후 '마지막 근로일로부터 7일 이내에 새롭게 일용직근로계약서체결을 아니할 경우에는 마지막 근로일로 근로관계가 종료된 것으로 본다'로 계약내용을 변경함) 이전의 계속근로기간은 매 근로계약체결 시점부터
# 당일 작업종료 시점까지이며 단절기간을 두고 다시 근로계약을 체결하는 경우에는 그날부터 새롭게 계속 근로기간이 기산되는 것으로 봐야 할 것이므로 '퇴직금이 발생하지 않아' 행정종결하였음을 알립니다
# *일용직근로자들의 임금*
# 위 사건을 검토한 결과, 임금에서 4대보험료, 세금, 직업소개수수료850원, 마지막 연장근로 1시간에 대한 미작업시간10분에 대한 임금상당액 명목으로 11%를 공제하였음이 확인되었고 이를 근거로 발생임금과 지급임금을 비교한 결과 미지급임금이 없는 것으로 판단하여 행정종결되었음을 알려드립니다
# <노동청본부의 상반된 회신내용 >
# 일용직근로자들의 근로계약서상 사용자는 주식회사 ****** 소속으로 가입되어있고 일용직근로자의 4대보험은 (주)******소속으로 가입되어 있으며 일용직노동자들에 대한 작업배치, 작업지시,안전교육 등 은 (주)******에서 수행하였고 직업소개소에서 알선인원명부, 일별투입명세서 등 을 제출(월2회)하면 월 2회 정산하여 지급해왔던 점을 종합해보면 일용직근로자들의 근로조건을 결정하고 업무상 상당한 지휘감독을 하는 근기법 상 사용자는 주신회사******로 판단되는 바, 일용직근로자를 소개한 직업소개소에서 임금등을 미리 선지급하고 근로계약서 작성업무를 수행했던 점 등이 확인되었다고해서 달리 판단할 것은 아니라고 사료됩니다
# *택배터미널 운영업무에 종사한 일용직근로자의 계속근로기간 인정방법*
# <근로자퇴직급여 보장법>제4조 제1항에 따라 사용자는 계속근로기간이 1년 이상이고 4주간을 평균하여 1주간의 소정근로시간이 15시간 이상인 근로자에게는 퇴직급여를 지급하여야 한다
#
# 저와 400여명의 제 동료들은 하루10시간 이상 매일 또는 주4~5일을 근무한 노동자들입니다
# 또한 해당 터미널 전 도급사(주)******는 해당 사업장에서 작업하던 근로자가 척추신경이 파열하는 사고가 있었음에도 구급차로 매우 각별한 처치가 아닌 일반 차량으로 이송하였고 산재처리한 근로자의 담당소개소를 압박해 받은 산재보험료를 토해 낸 일도 있었습니다
# 전 사업주는 이런 악질의 사업주였으며 현재 의도적으로 행적을 감춤으로서 사건을 계속 은폐또는 회피를 시도하고 있는 것 입니다
# 일용직근로자들의 퇴직금을 받을 권리를 지켜주십시요
# 전국의 일용직근로자는 지금도 법의 사각지대에서 생명에 위협받으며 하루하루 일하고 있고 고통 속에 생존권에 위협받고 있습니다
# 부디 우리의 권리를 외면하지 마십시오!!!!
# ▢ 조달청의 과도한 이중처벌 기업 죽이기 제도 개정요청
#
# 조달청 물품 다수공급자계약 2단계경쟁 업무처리기준 관련
# 품질관리 제재 이중처벌(거래정지 및 감점제재 2년간 부과) 조항 개정 요청
#
# ○ 조달청의 위엄한 이중처벌의 편익보다 국민의 권익침해 및 기업의 생존을 어렵게 하고 공정성과 공익성 또한 부족하여, 결국 국민의 피해가 매우 더 큰 과도한 이중처벌제도의 개선을 요청합니다.
# [허가(등록을 고치면 위법) 그대로 납품하므로 잘못이 없는데도 검사제도의 맹점을 간과했다고 처벌한다면 맹한 제품만 처벌 해야지 그 처벌 이후 또다시 이중으로 잘못 없는 다른 좋은 제품까지 모두를 과도하게 이중처벌하면 안돼요.]
#
# ◎ 요청내용 :
# ① 조달청이 선정한 다수공급자제품을 공공기관에 납품하는 자가 최초 1억원 이후 2억원 납품시마다 실시하는 ‘조달물자 검사 대상물품 및 검사기준’ 과 “조달물자 전문기관검사 업무규정” 과 ‘물품구매계약 품질관리 특수조건’ 및 ‘조달청 물품 다수공급자계약 2단계경쟁 업무처리기준’에 따라 전문검사기관 검사에 불합격한 경우 ⟪해당제품 거래정지와 MAS2(다수공급자계약제품 경쟁입찰)단계 입찰에서 낙찰자 선정평가 시 해당 사업자의 다른제품까지 모두 품질관리 점수항목 감점제재로 이중처벌⟫을 하고 있으나 계약상대자인 납품자가 조달청에서 당초 선정 등록 시 제출한 시험성적서 성능 그대로 납품하는 제품의 품질검사 시험인 경우 당초 성능대로 납품하는지의 품질유지 확인 검사이므로 당초 값으로 시험하는 것이 타당한데도 이 당초 값을 적용하지 않고 더 높은 값으로 시험하여 불합격된 결과를 불복하며 ‘납품자(계약상대자)가 재시험 요청하거나, 구매자(수요기관)가 재시험을 요청할 경우 재시험을 수용’해야 합니다.
#
# ※ 개정요청 : 「조달물자 전문기관검사 업무규정」 제23조(시험결과에 대한 이의)
# “① 계약상대자 및 수요기관의 장이 시험결과에 대하여 이의를 제기하면 조달청장은 시험방법 및 절차 등을 고려하여 확인시험이 필요하다고 판단하는 경우 전문검사기관의 장에게 확인시험을 요청하고~” 의 위 규정에서 조달청장이 ‘필요하다고 판단’하는 고려의 기준근거가 명확하지 않고 적용사례를 찾아보기 힘들며 ‘갑’만을 위한 문구로 ‘을’에게는 불리한 전형적인 ‘갑’의 입장으로 판단하겠다는 내용을 삭제하고
# “① 계약상대자 및 수요기관의 장이 시험결과에 대하여 이의를 제기하면 조달청장은 전문검사기관의 장에게 확인시험을 요청하고~” 로 수정하여 모두에게 동등하며 분명하고 명확한 문구로 개정을 요청합니다.
# - 상기와 관련하여 공공기관(구매자, 수요기관)이 전문검사기관의 검사(불합격 결과)를 신뢰하지 못해 수요기관이 자체 검사로 변경하고 ‘수요기관의 자체 검사에 합격’하여 납품한 경우, 원인행위가 소멸되었으므로 거래정지 뿐만이 아니라 품질관리 감점제재를 하지 않아야하며 이미 처분한 거래정지도 즉시 소멸하여야 하고 이후 납품자가 신청하는 재계약 및 계약연장 등에 불이익 또한 없도록 해야 합니다.
#
# 1. 조달청 나라장터종합쇼핑몰 제품 품질관리제도의 가혹한 2중 처벌의 규정 : 불합격 제품의 거래정지뿐만 아니라 그 기업(사업자)의 다른 일반제품 모두를 또다시 2중 처벌로 감점제재하는 것은 해당기업의 다른 제품의 사업까지 규제하여 기업을 못하게 하는 헌법을 초월하는 너무 가혹한 처벌입니다.
#
# (1) 조달청이 품질관리 전문검사기관을 통한 기업 죽이기 유형
# - MAS2단계 경쟁입찰 해당 쇼핑몰 등록제품의 엄격한 품질관리 검사조건으로 제품 가격기준 최초 납품의 경우 1억원이상 이후 2억원이상 납품시 마다 매번 납품할 제품의 품질검사를 납품자가 많은 비용을 부담하며 전문검사기관에 의뢰 실시하여 불합격시 해당 등록제품의 거래정지와 또 다른 처벌인 감점제재로 이 거래정지 기간과 감점제재 기간 또한 크게 다른 이중처벌의 품질관리 제도를 운영(품질검사 불합격시 거래정지 1개월과 감점 제재 2년간(기업생존이 어려운 오랜기간)의 이중처벌을 함)
#
# - 위 당초 불합격 처분 받은 제품은 거래정지(1개월) 제재가 끝나 그 동일제품을 조달청 나라장터종합쇼핑몰을 통해 공공기관에 납품하고 있는데 위 ‘동일 제조사가 나라장터쇼핑몰에 등록한 다른 모든 제품’의 품질관리 점수에 감점 제재(2년)로 다른 제품까지 연좌제식으로 처벌하는 것은 기업 죽이기 제도와 다를 바 없음[당초 합격당시 제품을 털끝 하나 고치지 않고(좋게 또는 나쁘게 고치면 위반) 납품하는 제품인데도 매우 극소수 1개 품목에 제조사가 제시한 등록 당시 당초 시험 값을 적용하지 않고 시험기준이내라고 하며 당초 시험 값보다 높은 값을 적용해서 시험하여 불합격 처분을 받은 기업에게 거래정지 뿐만이 아니라 다른 종류의 모든 제품에 품질관리 점수까지 감점제재]
#
# - 품질관리가 엄격해야하는 것에는 동의하나, MAS(다수공급자계약제품)2단계 경쟁입찰의 품질관리 점수 감점제재는 불합격 받았던 제품의 사업자만 같아도 그 기업의 다른 제품까지 모두 2점(종합평가방식) ~ 6점(표준평가방식)을 감점하고 있음, 이는 MAS2단계 경쟁입찰에서 업체들의 평가 합계점수가 1점이내의 근소한 점수차이로 1순위에 선정되는 입찰임을 감안할 때 2~6점의 감점은 매우 큰 점수로 MAS2단계 경쟁입찰에서 사실상 낙찰 선정되기는 불가능하여 기업생존 유지가 어려움(MAS2단계 경쟁입찰을 피해서 수의계약에만 의존하여 사업하는 것은 고용창출도 고용유지도 할 수 없는 고용 없는 1인 기업정도가 아닌 이상 기업생존이 사실상 불가능)
#
# (2) 검사결과 불합격된 제품만 제재 필요
# - 품질관리 검사에 불합격제품만 거래정지 처벌을 하고 연좌제 성격의 이중처벌인 다른 제품을 감점제재로 처벌하는 것은 금지해야 합니다.(예시, 불합격 제품은 ‘공기조화기’인데 사업자가 같다고 정상제품인 ‘공기청정기’까지 제재해서는 안됨)
#
# 2. 사후 검증에 의해 잘 못이 없는 기업에게 처벌이 이루어졌다고 판결된다면 그에 따른 피해는 회복이 불가능하므로 품질관리 절차와 제도의 개정이 절실히 필요합니다.
#
# (1) 정부조달제도의 납품자가 품질검사에 불복하여 재시험 요청하거나 구매 수요기관에서 재시험을 요청할 경우 “재시험 수용” 규정을 추가하여 억울한 피해자가 없도록 해주세요.
# - 납품기업이 많은 검사비용을 부담하며 조달업무 규정에 의해 실시하는 전문검사기관 품질검사에 이해충돌 또는 검사의 잘못이 있을 수 있어 납품기업의 재시험 요청시 즉시 ‘재시험을 수용’하여 재시험 실시해야 합니다.
# [단, 납품기업의 무분별한 불복의 재시험 요청을 없애기 위해 재시험 결과에서도 불합격될 경우 해당 처벌(제재)을 최고 수위로 엄격히 적용]
#
# (당초 조달청 나라장터쇼핑몰에 제품 등록시 동일제품 그대로 납품하는 제품을 전문검사기관의 품질검사 시 당초 등록당시 제품성능 평가에 적용한 시험 값을 제시했으나 그 시험 값으로 성능시험을 하지 않아 불합격된 경우 등 혹여 절차나 기준의 착오 또는 단순 실수 등과 같이 기업의 고의가 없는 보통의 성실한 기업에게 큰 피해가 발생할 수 있으므로 그 피해에 따른 억울함이 없도록 소명의 기회로 계약대상자(납품기업 또는 수요기관)가 재시험을 요청할 경우 민원 재검증 등 인도적 차원에서 이를 수용하고 재시험을 실시해야 조달청의 품질검사 제도를 납품자와 구매자가 신뢰할 수 있음)
#
#
# ○ 조달청의 위엄적 처벌이 하도 억울하여 헌법을 참조 비유해 봅니다.
# (수요기관에서도 이런 조달청의 위엄적 처벌을 ‘갑’질이라고 합니다.)
#
# ◉ 대한민국헌법 제13조 제1항이 정한 “이중처벌 금지의 원칙”
# (슈퍼 갑이며 공공기관 납품자선정과 구매 및 검사를 관장하는 조달청이 위탁 실시하는 전문검사기관의 검사결과를 계약대상자인 납품자와 구매자가 불복하여 재시험요청을 했으나 거절하고 거래정지 처벌에 이어 또 다시 다른 제품까지 '이중처벌 제재'를 하는 억울한 건에 수요기관(공공기관)인 구매자가 조달청이 위탁하여 실시한 검사결과를 신뢰하지 못해 수요기관인 구매자가 직접 검사를 하여 합격 납품한 경우 그 처벌을 소멸해야 합니다.)
#
# 제13조 ①모든 국민은 행위 시의 법률에 의하여 범죄를 구성하지 아니하는 행위로 소추되지 아니하며, 동일한 범죄에 대하여 거듭 처벌받지 아니한다.
# ②모든 국민은 소급입법에 의하여 참정권의 제한을 받거나 재산권을 박탈당하지 아니한다.
# ③모든 국민은 자기의 행위가 아닌 친족의 행위로 인하여 불이익한 처우를 받지 아니한다.
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-22-1e11b6c6abe2> in <module>
#      27             time.sleep(5)
#      28
# ---> 29         pageNext = driver.find_element_by_xpath('//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[{}]/a[{}]'.format(count,i))
#      30         pageNext.click()
#      31         time.sleep(5)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="cont_view"]/div[2]/div/div/div[2]/div[2]/div[4]/div/div[4]/div/div[3]/a[9]"}
#   (Session info: chrome=99.0.4844.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F69943+2595139]
# 	Ordinal0 [0x00EFC9F1+2148849]
# 	Ordinal0 [0x00DF4528+1066280]
# 	Ordinal0 [0x00E20FD4+1249236]
# 	Ordinal0 [0x00E211CB+1249739]
# 	Ordinal0 [0x00E4D812+1431570]
# 	Ordinal0 [0x00E3BA34+1358388]
# 	Ordinal0 [0x00E4BAF2+1424114]
# 	Ordinal0 [0x00E3B806+1357830]
# 	Ordinal0 [0x00E16086+1204358]
# 	Ordinal0 [0x00E16F96+1208214]
# 	GetHandleVerifier [0x0110B232+1658114]
# 	GetHandleVerifier [0x011C312C+2411516]
# 	GetHandleVerifier [0x00FFF261+560433]
# 	GetHandleVerifier [0x00FFE366+556598]
# 	Ordinal0 [0x00F0286B+2173035]
# 	Ordinal0 [0x00F075F8+2192888]
# 	Ordinal0 [0x00F076E5+2193125]
# 	Ordinal0 [0x00F111FC+2232828]
# 	BaseThreadInitThunk [0x757CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77277A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77277A4E+238]
